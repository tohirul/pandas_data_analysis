# %%
import pandas as pd

# %%
student_data= pd.read_csv("student_data.csv")
student_data
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
student_data.columns
# Out:
# Index(['StudentID', 'FullName', 'Data Structure Marks', 'Algorithm Marks',
#        'Python Marks', 'CompletionStatus', 'EnrollmentDate', 'Instructor',
#        'Location'],
#       dtype='object')

# %%
student_data["FullName"]
# type(student_data["FullName"])
# Out:
# 0          Alif Rahman
# 1        Fatima Akhter
# 2        Imran Hossain
# 3     Jannatul Ferdous
# 4          Kamal Uddin
# 5          Laila Begum
# 6       Mahmudul Hasan
# 7          Nadia Islam
# 8           Omar Faruq
# 9         Priya Sharma
# 10        Rahim Sheikh
# 11     Sadia Chowdhury
# 12        Tanvir Ahmed
# 13          Urmi Akter
# 14        Wahiduzzaman
# 15        Ziaur Rahman
# 16         Afsana Mimi
# 17         Babul Ahmed
# 18        Faria Rahman
# 19          Nasir Khan
# 20                 NaN
# Name: FullName, dtype: object

# %%
student_data.loc[0]
# Out:
# StudentID                    PH1001
# FullName                Alif Rahman
# Data Structure Marks           85.0
# Algorithm Marks                85.0
# Python Marks                   88.0
# CompletionStatus          Completed
# EnrollmentDate           2024-01-15
# Instructor                Mr. Karim
# Location                      Dhaka
# Name: 0, dtype: object

# %%
student_data.loc[1]
# Out:
# StudentID                      PH1002
# FullName                Fatima Akhter
# Data Structure Marks             92.0
# Algorithm Marks                  92.0
# Python Marks                      NaN
# CompletionStatus          In Progress
# EnrollmentDate             2024-01-20
# Instructor                  Ms. Salma
# Location                   Chattogram
# Name: 1, dtype: object

# %%
student_data.loc[0:5]
# Out:
#   StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0    PH1001       Alif Rahman                  85.0             85.0
# 1    PH1002     Fatima Akhter                  92.0             92.0
# 2    PH1003     Imran Hossain                  88.0             88.0
# 3    PH1004  Jannatul Ferdous                  78.0             78.0
# 4    PH1005       Kamal Uddin                   NaN              NaN
# 5    PH1006       Laila Begum                  75.0             75.0
#
#    Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 0          88.0        Completed     2024-01-15  Mr. Karim       Dhaka
# 1           NaN      In Progress     2024-01-20  Ms. Salma  Chattogram
# 2          85.0        Completed     2024-02-10  Mr. Karim       Dhaka
# 3          82.0        Completed     2024-02-12  Ms. Salma      Sylhet
# 4          95.0      In Progress     2024-03-05  Mr. Karim  Chattogram
# ...

# %%
student_data.loc[[2,4,18]]
# Out:
#    StudentID       FullName  Data Structure Marks  Algorithm Marks  \
# 2     PH1003  Imran Hossain                  88.0             88.0
# 4     PH1005    Kamal Uddin                   NaN              NaN
# 18    PH1019   Faria Rahman                   NaN              NaN
#
#     Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 2           85.0        Completed     2024-02-10  Mr. Karim       Dhaka
# 4           95.0      In Progress     2024-03-05  Mr. Karim  Chattogram
# 18           NaN      Not Started     2025-09-15  Mr. David  Chattogram

# %%
student_data.loc[1:9,["FullName", "Python Marks","Algorithm Marks", "Data Structure Marks"]]
# Out:
#            FullName  Python Marks  Algorithm Marks  Data Structure Marks
# 1     Fatima Akhter           NaN             92.0                  92.0
# 2     Imran Hossain          85.0             88.0                  88.0
# 3  Jannatul Ferdous          82.0             78.0                  78.0
# 4       Kamal Uddin          95.0              NaN                   NaN
# 5       Laila Begum          78.0             75.0                  75.0
# 6    Mahmudul Hasan           NaN             80.0                  80.0
# 7       Nadia Islam          85.0             81.0                  81.0
# 8        Omar Faruq          76.0             72.0                  72.0
# 9      Priya Sharma          88.0             89.0                  89.0

# %%
df = pd.read_csv("student_data.csv")

student_data =df.set_index('StudentID')
student_data
# Out:
#                    FullName  Data Structure Marks  Algorithm Marks  \
# StudentID
# PH1001          Alif Rahman                  85.0             85.0
# PH1002        Fatima Akhter                  92.0             92.0
# PH1003        Imran Hossain                  88.0             88.0
# PH1004     Jannatul Ferdous                  78.0             78.0
# PH1005          Kamal Uddin                   NaN              NaN
# PH1006          Laila Begum                  75.0             75.0
# PH1007       Mahmudul Hasan                  80.0             80.0
# PH1008          Nadia Islam                  81.0             81.0
# PH1009           Omar Faruq                  72.0             72.0
# PH1010         Priya Sharma                  89.0             89.0
# PH1011         Rahim Sheikh                   NaN              NaN
# PH1012      Sadia Chowdhury                  85.0             85.0
# PH1013         Tanvir Ahmed                  75.0             75.0
# ...

# %%
student_data.rename(columns={"FullName": "Name"})
# Out:
#                        Name  Data Structure Marks  Algorithm Marks  \
# StudentID
# PH1001          Alif Rahman                  85.0             85.0
# PH1002        Fatima Akhter                  92.0             92.0
# PH1003        Imran Hossain                  88.0             88.0
# PH1004     Jannatul Ferdous                  78.0             78.0
# PH1005          Kamal Uddin                   NaN              NaN
# PH1006          Laila Begum                  75.0             75.0
# PH1007       Mahmudul Hasan                  80.0             80.0
# PH1008          Nadia Islam                  81.0             81.0
# PH1009           Omar Faruq                  72.0             72.0
# PH1010         Priya Sharma                  89.0             89.0
# PH1011         Rahim Sheikh                   NaN              NaN
# PH1012      Sadia Chowdhury                  85.0             85.0
# PH1013         Tanvir Ahmed                  75.0             75.0
# ...

# %%
df = pd.read_csv("student_data.csv")
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
df.drop(1, inplace=True)
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# ...

# %%
df.drop("Location", axis=1, inplace=True)
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# ...

# %%
df.loc[4, "Data Structure Marks"]=85
df.loc[4, "Algorithm Marks"]=75
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                  85.0             75.0
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# ...

# %%
df.head()
# Out:
#   StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0    PH1001       Alif Rahman                  85.0             85.0
# 2    PH1003     Imran Hossain                  88.0             88.0
# 3    PH1004  Jannatul Ferdous                  78.0             78.0
# 4    PH1005       Kamal Uddin                  85.0             75.0
# 5    PH1006       Laila Begum                  75.0             75.0
#
#    Python Marks CompletionStatus EnrollmentDate Instructor
# 0          88.0        Completed     2024-01-15  Mr. Karim
# 2          85.0        Completed     2024-02-10  Mr. Karim
# 3          82.0        Completed     2024-02-12  Ms. Salma
# 4          95.0      In Progress     2024-03-05  Mr. Karim
# 5          78.0        Completed     2024-03-08  Ms. Salma

# %%
df.loc[1:3, "Python Marks"]+=3
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                  85.0             75.0
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# ...

# %%
for i in df.itertuples(index=False):
        print(i)
# Out:
# Pandas(StudentID='PH1001', FullName='Alif Rahman', _2=85.0, _3=85.0, _4=88.0, CompletionStatus='Completed', EnrollmentDate='2024-01-15', Instructor='Mr. Karim')
# Pandas(StudentID='PH1003', FullName='Imran Hossain', _2=88.0, _3=88.0, _4=88.0, CompletionStatus='Completed', EnrollmentDate='2024-02-10', Instructor='Mr. Karim')
# Pandas(StudentID='PH1004', FullName='Jannatul Ferdous', _2=78.0, _3=78.0, _4=85.0, CompletionStatus='Completed', EnrollmentDate='2024-02-12', Instructor='Ms. Salma')
# Pandas(StudentID='PH1005', FullName='Kamal Uddin', _2=85.0, _3=75.0, _4=95.0, CompletionStatus='In Progress', EnrollmentDate='2024-03-05', Instructor='Mr. Karim')
# Pandas(StudentID='PH1006', FullName='Laila Begum', _2=75.0, _3=75.0, _4=78.0, CompletionStatus='Completed', EnrollmentDate='2024-03-08', Instructor='Ms. Salma')
# Pandas(StudentID='PH1007', FullName='Mahmudul Hasan', _2=80.0, _3=80.0, _4=nan, CompletionStatus='In Progress', EnrollmentDate='2024-04-01', Instructor='Mr. Karim')
# ...

# %%
sorted = df.sort_values("EnrollmentDate")
sorted
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                  85.0             75.0
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# ...

# %%
completed = df.loc[df.CompletionStatus == "Completed"]
completed
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 5     PH1006       Laila Begum                  75.0             75.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# 16    PH1017       Afsana Mimi                  90.0             90.0
# 17    PH1018       Babul Ahmed                  88.0             88.0
# ...

# %%
not_started = df.loc[df.CompletionStatus== "Not Started"]
not_started
# Out:
#    StudentID      FullName  Data Structure Marks  Algorithm Marks  \
# 13    PH1014    Urmi Akter                   NaN              NaN
# 18    PH1019  Faria Rahman                   NaN              NaN
#
#     Python Marks CompletionStatus EnrollmentDate Instructor
# 13           NaN      Not Started     2024-07-09  Ms. Salma
# 18           NaN      Not Started     2025-09-15  Mr. David
