# %%
import pandas as pd

# %%
list_series = pd.Series([10,20,30,40,50],name="Numbers")
print(list_series)
print(type(list_series))
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: Numbers, dtype: int64
# <class 'pandas.core.series.Series'>

# %%
bio_list = [
    ["Adam", 25, "Havana"],
    ["Ruth", 19, "LA"],
    ["Brad", 24, "Colorado"]
]

bio_data = pd.DataFrame(bio_list,columns=["Name","Age", "City"],index=[1,2,3])
bio_data
# Out:
#    Name  Age      City
# 1  Adam   25    Havana
# 2  Ruth   19        LA
# 3  Brad   24  Colorado

# %%
student_data = pd.read_csv("student_data.csv")
student_data
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
data_cols= student_data.columns
data_rows = len(student_data)
print("Number of Columns: ",len(data_cols))
print("Number of Rows: ",(data_rows))

col_FullName_type = student_data.FullName.dtypes
col_Python_Marks_type = student_data["Python Marks"].dtypes
col_EnrollmentDate_type = student_data.EnrollmentDate.dtypes

print("FullName Type: ", col_FullName_type)
print("Python Marks Type: ", col_Python_Marks_type)
print("EnrollmentDate Type: ", col_EnrollmentDate_type)
# Out:
# Number of Columns:  9
# Number of Rows:  20
# FullName Type:  object
# Python Marks Type:  float64
# EnrollmentDate Type:  object

# %%
student_data_statistics = student_data.describe()
student_data_statistics
# Out:
#        Data Structure Marks  Algorithm Marks  Python Marks
# count             16.000000        16.000000     15.000000
# mean              84.000000        84.000000     85.666667
# std                6.501282         6.501282      5.394000
# min               72.000000        72.000000     76.000000
# 25%               79.500000        79.500000     83.000000
# 50%               85.500000        85.500000     85.000000
# 75%               88.250000        88.250000     88.500000
# max               94.000000        94.000000     95.000000

# %%
demo_data = {
    'Product': ['Pen', 'Book', 'Eraser', 'Pencil'],
    'Price': [10, 50, 5, 7],
    'Quantity': [100, 60, 200, 150]
}

# %%
data = pd.DataFrame(demo_data)

# %%
data
# Out:
#   Product  Price  Quantity
# 0     Pen     10       100
# 1    Book     50        60
# 2  Eraser      5       200
# 3  Pencil      7       150

# %%
data_cols = data.columns
data_cols
# Out:
# Index(['Product', 'Price', 'Quantity'], dtype='object')

# %%
data_index = data.index

data_index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
data_price_col = data.Price

data_price_col
# Out:
# 0    10
# 1    50
# 2     5
# 3     7
# Name: Price, dtype: int64

# %%
data_product_col = data.Product

data_product_col
# Out:
# 0       Pen
# 1      Book
# 2    Eraser
# 3    Pencil
# Name: Product, dtype: object

# %%
data_selected_row = data[0:3]

data_selected_row
# Out:
#   Product  Price  Quantity
# 0     Pen     10       100
# 1    Book     50        60
# 2  Eraser      5       200

# %%
data
# Out:
#   Product  Price  Quantity
# 0     Pen     10       100
# 1    Book     50        60
# 2  Eraser      5       200
# 3  Pencil      7       150

# %%
data.loc[1:2,["Product","Price"]]
# Out:
#   Product  Price
# 1    Book     50
# 2  Eraser      5

# %%
data[:1]
# Out:
#   Product  Price  Quantity
# 0     Pen     10       100

# %%
data.loc[0]
# Out:
# Product     Pen
# Price        10
# Quantity    100
# Name: 0, dtype: object

# %%
data.loc[:,["Price"]]
# Out:
#    Price
# 0     10
# 1     50
# 2      5
# 3      7

# %%
data.loc[:,"Product"]
# Out:
# 0       Pen
# 1      Book
# 2    Eraser
# 3    Pencil
# Name: Product, dtype: object

# %%
data.iloc[0]
# Out:
# Product     Pen
# Price        10
# Quantity    100
# Name: 0, dtype: object

# %%
data.iloc[:,[data.columns.get_loc("Product"), data.columns.get_loc("Price")]]
# Out:
#   Product  Price
# 0     Pen     10
# 1    Book     50
# 2  Eraser      5
# 3  Pencil      7

# %%
data.iloc[:,[1]]
# Out:
#    Price
# 0     10
# 1     50
# 2      5
# 3      7

# %%
data[1:3][["Product","Price"]]
# Out:
#   Product  Price
# 1    Book     50
# 2  Eraser      5

# %%
student_data
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
res_data = student_data[0:4][["StudentID", "FullName","Algorithm Marks"]].reset_index(drop=True)
res_data.index+=1

res_data
# Out:
#   StudentID          FullName  Algorithm Marks
# 1    PH1001       Alif Rahman             85.0
# 2    PH1002     Fatima Akhter             92.0
# 3    PH1003     Imran Hossain             88.0
# 4    PH1004  Jannatul Ferdous             78.0

# %%
employee_data = pd.DataFrame(
    [
        ["Raju", "YouTube", "124000"],
        ["Alex", "YouTube", "89000"],
        ["Brett", "YouTube", "140000"],
        ["Grett", "YouTube","140000"]
        ], columns=["Name", "Department", "Salary"]
)
sorted_data =employee_data.sort_values(["Salary", "Name"],ascending=[True, False]).reset_index(drop=True)
sorted_data.index+=1

sorted_data
# Out:
#     Name Department  Salary
# 1   Raju    YouTube  124000
# 2  Grett    YouTube  140000
# 3  Brett    YouTube  140000
# 4   Alex    YouTube   89000

# %%
students_info = pd.DataFrame(
    {
        "Name": ["Alice", "Bob", "Charlie", "Diana", "Ethan", "Fiona", "George", "Hannah"],
        "Score": [85, 92, 78, 38, 95, 67, 80, 90]
    }
)

students_info
# Out:
#       Name  Score
# 0    Alice     85
# 1      Bob     92
# 2  Charlie     78
# 3    Diana     38
# 4    Ethan     95
# 5    Fiona     67
# 6   George     80
# 7   Hannah     90

# %%
above_target = students_info[students_info.Score > 60].reset_index(drop=True)
above_target
# Out:
#       Name  Score
# 0    Alice     85
# 1      Bob     92
# 2  Charlie     78
# 3    Ethan     95
# 4    Fiona     67
# 5   George     80
# 6   Hannah     90
